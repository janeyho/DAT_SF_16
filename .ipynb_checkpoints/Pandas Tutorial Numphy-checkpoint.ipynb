# %%
# Import libraries needed
import pandas as pd
from numpy import random
import matplotlib.pyplot as plt
import sys 

# Enable inline plotting
# %matplotlib inline

# %%
print 'Python version' + sys.version
print 'Pandas version' + pd.__version__
# Out:
# Python version2.7.10 |Anaconda 2.3.0 (x86_64)| (default, May 28 2015, 17:04:42)
# [GCC 4.2.1 (Apple Inc. build 5577)]
# Pandas version0.16.2

# %%
# The initial set of baby names
names = ['Bob', 'Jessica', 'Mary', 'John', 'Mel']

# %%
random.seed?

# %%
random.randint?

# %%
len?

# %%
range?

# %%
zip?

# %%
len(names)
# Out:
# 5

# %%
random.seed(500)
random_names = [names[random.randint(low=0,high=len(names))] for i in range(1000)]

# Print first 10 records
random_names[:10]
# Out:
# ['Mary',
#  'Jessica',
#  'Jessica',
#  'Bob',
#  'Jessica',
#  'Jessica',
#  'Jessica',
#  'Mary',
#  'Mary',
#  'Mary']

# %%
random_names
# Out:
# ['Mary',
#  'Jessica',
#  'Jessica',
#  'Bob',
#  'Jessica',
#  'Jessica',
#  'Jessica',
#  'Mary',
#  'Mary',
#  'Mary',
#  'John',
#  'Bob',
#  'Bob',
#  'Mary',
#  'Mary',
#  'John',
#  'Mel',
#  'Mary',
#  'Mel',
#  'John',
#  'John',
#  'Mel',
#  'Jessica',
#  'John',
#  'Jessica',
#  'Mary',
#  'Mary',
#  'John',
#  'Jessica',
#  'Bob',
#  'John',
#  'Jessica',
#  'Jessica',
#  'John',
#  'Bob',
#  'Mel',
#  'Jessica',
#  'Mel',
#  'Mel',
#  'Mary',
#  'Jessica',
#  'Mel',
#  'Mel',
#  'Mel',
#  'Mel',
#  'Bob',
#  'John',
#  'Jessica',
#  'Jessica',
#  'Bob',
#  'John',
#  'John',
#  'Jessica',
#  'Bob',
#  'Bob',
#  'John',
#  'John',
#  'John',
#  'Mel',
#  'Bob',
#  'Mel',
#  'Mel',
#  'Jessica',
#  'Mary',
#  'John',
#  'John',
#  'Bob',
#  'John',
#  'Mary',
#  'Bob',
#  'John',
#  'Mel',
#  'John',
#  'John',
#  'Bob',
#  'Mary',
#  'Bob',
#  'Jessica',
#  'Mel',
#  'Jessica',
#  'Bob',
#  'Mel',
#  'Bob',
#  'John',
#  'Jessica',
#  'Jessica',
#  'John',
#  'Bob',
# ...

# %%
# The number of births per name for the year 1880
births = [random.randint(low=0,high=1000) for i in range(1000)]
births[:10]
# Out:
# [968, 155, 77, 578, 973, 124, 155, 403, 199, 191]

# %%
births
# Out:
# [968,
#  155,
#  77,
#  578,
#  973,
#  124,
#  155,
#  403,
#  199,
#  191,
#  769,
#  88,
#  43,
#  393,
#  164,
#  45,
#  148,
#  609,
#  134,
#  726,
#  106,
#  355,
#  774,
#  214,
#  732,
#  362,
#  682,
#  141,
#  433,
#  892,
#  328,
#  151,
#  737,
#  200,
#  626,
#  679,
#  812,
#  481,
#  723,
#  98,
#  76,
#  911,
#  948,
#  698,
#  539,
#  806,
#  885,
#  785,
#  750,
#  233,
#  442,
#  170,
#  363,
#  913,
#  186,
#  510,
#  998,
#  12,
#  804,
#  705,
#  900,
#  727,
#  643,
#  34,
#  580,
#  287,
#  382,
#  5,
#  204,
#  392,
#  982,
#  809,
#  62,
#  220,
#  458,
#  738,
#  502,
#  352,
#  956,
#  326,
#  791,
#  724,
#  414,
#  51,
#  295,
#  463,
#  922,
#  693,
#  353,
#  378,
#  836,
#  10,
#  279,
#  778,
#  10,
#  370,
#  739,
#  682,
#  469,
#  324,
#  612,
#  721,
#  410,
#  474,
#  294,
#  128,
#  622,
#  588,
#  708,
#  286,
#  740,
#  112,
#  128,
#  195,
#  458,
#  828,
#  576,
#  726,
#  744,
#  449,
#  814,
#  678,
#  327,
#  837,
#  904,
#  592,
# ...

# %%
# Merge the names and the births data set using zip function
BabyDataSet = zip(random_names,births)

# %%
BabyDataSet
# Out:
# [('Mary', 968),
#  ('Jessica', 155),
#  ('Jessica', 77),
#  ('Bob', 578),
#  ('Jessica', 973),
#  ('Jessica', 124),
#  ('Jessica', 155),
#  ('Mary', 403),
#  ('Mary', 199),
#  ('Mary', 191),
#  ('John', 769),
#  ('Bob', 88),
#  ('Bob', 43),
#  ('Mary', 393),
#  ('Mary', 164),
#  ('John', 45),
#  ('Mel', 148),
#  ('Mary', 609),
#  ('Mel', 134),
#  ('John', 726),
#  ('John', 106),
#  ('Mel', 355),
#  ('Jessica', 774),
#  ('John', 214),
#  ('Jessica', 732),
#  ('Mary', 362),
#  ('Mary', 682),
#  ('John', 141),
#  ('Jessica', 433),
#  ('Bob', 892),
#  ('John', 328),
#  ('Jessica', 151),
#  ('Jessica', 737),
#  ('John', 200),
#  ('Bob', 626),
#  ('Mel', 679),
#  ('Jessica', 812),
#  ('Mel', 481),
#  ('Mel', 723),
#  ('Mary', 98),
#  ('Jessica', 76),
#  ('Mel', 911),
#  ('Mel', 948),
#  ('Mel', 698),
#  ('Mel', 539),
#  ('Bob', 806),
#  ('John', 885),
#  ('Jessica', 785),
#  ('Jessica', 750),
#  ('Bob', 233),
#  ('John', 442),
#  ('John', 170),
#  ('Jessica', 363),
#  ('Bob', 913),
# ...

# %%
df = pd.DataFrame(data = BabyDataSet, columns =['Names', 'Births'])

# %%
df
# Out:
#        Names  Births
# 0       Mary     968
# 1    Jessica     155
# 2    Jessica      77
# 3        Bob     578
# 4    Jessica     973
# 5    Jessica     124
# 6    Jessica     155
# 7       Mary     403
# 8       Mary     199
# 9       Mary     191
# 10      John     769
# 11       Bob      88
# 12       Bob      43
# 13      Mary     393
# 14      Mary     164
# 15      John      45
# 16       Mel     148
# 17      Mary     609
# 18       Mel     134
# 19      John     726
# 20      John     106
# 21       Mel     355
# 22   Jessica     774
# 23      John     214
# 24   Jessica     732
# 25      Mary     362
# 26      Mary     682
# 27      John     141
# 28   Jessica     433
# 29       Bob     892
# ..       ...     ...
# 970  Jessica     572
# 971  Jessica     639
# 972  Jessica     566
# 973      Mel     739
# 974      Bob      78
# 975     John     150
# 976     Mary     463
# 977      Bob     715
# 978     John     118
# 979      Mel     122
# 980  Jessica     276
# ...

# %%
# Export to CSV file
df.to_csv('births1880.txt',index=False,header=False)

# %%
pd.read_csv?

# %%
Location = r'~/GeneralAssembly/DAT_SF_16/births1880.txt'
df = pd.read_csv(Location)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 999 entries, 0 to 998
# Data columns (total 2 columns):
# Mary    999 non-null object
# 968     999 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 23.4+ KB

# %%
df.head()
# Out:
#       Mary  968
# 0  Jessica  155
# 1  Jessica   77
# 2      Bob  578
# 3  Jessica  973
# 4  Jessica  124

# %%
df = pd.read_csv(Location, header=None)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 2 columns):
# 0    1000 non-null object
# 1    1000 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 23.4+ KB

# %%
df.tail()
# Out:
#            0    1
# 995     John  151
# 996  Jessica  511
# 997     John  756
# 998  Jessica  294
# 999     John  152

# %%
df = pd.read_csv(Location, names = ['Names', 'Births'])
df.head(5)
# Out:
#      Names  Births
# 0     Mary     968
# 1  Jessica     155
# 2  Jessica      77
# 3      Bob     578
# 4  Jessica     973

# %%
import os
os.remove(r'~/GeneralAssembly/DAT_SF_16/births1880.txt')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-34-d4aaa735f9c7> in <module>()
#       1 import os
# ----> 2 os.remove(r'~/GeneralAssembly/DAT_SF_16/births1880.txt')
#
# OSError: [Errno 2] No such file or directory: '~/GeneralAssembly/DAT_SF_16/births1880.txt'

# %%
df['Names'].unique()
# Out:
# array(['Mary', 'Jessica', 'Bob', 'John', 'Mel'], dtype=object)

# %%
for x in df['Names'].unique():
    print x
# Out:
# Mary
# Jessica
# Bob
# John
# Mel

# %%
print df['Names'].describe()
# Out:
# count     1000
# unique       5
# top        Bob
# freq       206
# Name: Names, dtype: object

# %%
name = df.groupby('Names')

# %%
df = name.sum()
df
# Out:
#          Births
# Names
# Bob      106817
# Jessica   97826
# John      90705
# Mary      99438
# Mel      102319
