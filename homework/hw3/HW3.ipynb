# %% [markdown]
# 2. Describe the content of the dataset in your own words
# This dataset gives information on the participant's number of times pregnant, plasma glucose concentration, diastolic blood presusre, triceps skin fodl thickness, 2-hour serum insulin, bmi, diabetes family history, age and whether or not the participant has diabetes. There are a total of 769 participants, all over the age of 21.
#
# 3. Describe the features and formulate hypothesis on which may be relevant in predicting diabetes
# There are nine features in this dataset:
#    1. Number of times pregnant
#    2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#    3. Diastolic blood pressure (mm Hg)
#    4. Triceps skin fold thickness (mm)
#    5. 2-Hour serum insulin (mu U/ml)
#    6. Body mass index (weight in kg/(height in m)^2)
#    7. Diabetes pedigree function
#    8. Age (years)
#    9. Class variable (0 or 1)
#
# hypothesis: high plasma glucose concentration, high bmi and diabetes pedigree closer to 1 may indicate larger liklihod of participant being in class = 1 (having diabetes).

# %%
# 4. Import the dataset to a Pandas dataframe and explore the data
import pandas as pd
location = r'~/GeneralAssembly/DAT_SF_16/homework/hw3/pima-indians-diabetes/pima-indians-diabetes.data'
data = pd.read_csv(location, names = ['TimesPregnant','PGC','DBP','Skin','SerumInsulin','BMI','Pedigree','Age','Class'])

# %%
# Look at data
data
# Out:
#      TimesPregnant  PGC  DBP  Skin  SerumInsulin   BMI  Pedigree  Age  Class
# 0                6  148   72    35             0  33.6     0.627   50      1
# 1                1   85   66    29             0  26.6     0.351   31      0
# 2                8  183   64     0             0  23.3     0.672   32      1
# 3                1   89   66    23            94  28.1     0.167   21      0
# 4                0  137   40    35           168  43.1     2.288   33      1
# 5                5  116   74     0             0  25.6     0.201   30      0
# 6                3   78   50    32            88  31.0     0.248   26      1
# 7               10  115    0     0             0  35.3     0.134   29      0
# 8                2  197   70    45           543  30.5     0.158   53      1
# 9                8  125   96     0             0   0.0     0.232   54      1
# 10               4  110   92     0             0  37.6     0.191   30      0
# ...

# %%
# Get data info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Times Pregnant    768 non-null int64
# PGC               768 non-null int64
# DBP               768 non-null int64
# Skin              768 non-null int64
# Serum Insulin     768 non-null int64
# BMI               768 non-null float64
# Pedigree          768 non-null float64
# Age               768 non-null int64
# Class             768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 60.0 KB

# %%
# There are no null values but see if there are values missing substituted by zero
# looking at Plasma Glucose Concentration levels 
#data['PGC'].min()
#data.sort(['PGC'], ascending=True)
# 5 records for 0 Plasma Glucose Concentration, records 75,502,349,342,182
#data[data.PGC == 0]
data[data.PGC == 0].count()
# Out:
# TimesPregnant    5
# PGC              5
# DBP              5
# Skin             5
# SerumInsulin     5
# BMI              5
# Pedigree         5
# Age              5
# Class            5
# dtype: int64

# %%
# Number of pgc = 0 and class = 0
#data[(data.PGC == 0)&(data.Class==0)]

# Mean of pgc != 0 and class = 0
#data[(data.PGC != 0)&(data.Class==0)]
#avg_PGC_0 = data.PGC[(data.PGC != 0)&(data.Class == 0)].mean()
#print avg_PGC_0
#data.PGC[(data.PGC == 0)&(data.Class == 0)] = avg_PGC_0

# Number of pgc = 0 and class = 1
#data[(data.PGC == 0)&(data.Class==1)]

# Mean of pgc != 0 and class = 1
avg_PGC_1 = data.PGC[(data.PGC != 0)&(data.Class == 1)].mean()
print avg_PGC_1
data.PGC[(data.PGC == 0)&(data.Class == 1)] = avg_PGC_1
# Out:
# 142.319548872
# /Users/janeho/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# looking for zeros for Diastolic blood pressure (mm Hg)
#data[data.DBP == 0]
data[data.DBP == 0].count()
# Out:
# TimesPregnant    35
# PGC              35
# DBP              35
# Skin             35
# SerumInsulin     35
# BMI              35
# Pedigree         35
# Age              35
# Class            35
# dtype: int64

# %%
#update 0 DBP with mean of class = 0 and class = 1 respectively
# Mean of DBP != 0 and class = 0
avg_DBP_0 = data.DBP[(data.DBP != 0)&(data.Class == 0)].mean()
print avg_DBP_0
data.DBP[(data.DBP == 0)&(data.Class == 0)] = avg_DBP_0


# Mean of DBP != 0 and class = 1
avg_DBP_1 = data.DBP[(data.DBP != 0)&(data.Class == 1)].mean()
print avg_DBP_1
data.DBP[(data.DBP == 0)&(data.Class == 1)] = avg_DBP_1
# Out:
# 70.8773388773
# 75.3214285714
# /Users/janeho/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Looking at Triceps skin fold thickness (mm)
#data[data.Skin == 0]
data[data.Skin == 0].count()
# Out:
# TimesPregnant    227
# PGC              227
# DBP              227
# Skin             227
# SerumInsulin     227
# BMI              227
# Pedigree         227
# Age              227
# Class            227
# dtype: int64

# %%
#update 0 Skin with mean of class = 0 and class = 1 respectively
# Mean of Skin != 0 and class = 0
avg_Skin_0 = data.Skin[(data.Skin != 0)&(data.Class == 0)].mean()
print avg_Skin_0
data.Skin[(data.Skin == 0)&(data.Class == 0)] = avg_Skin_0


# Mean of Skin != 0 and class = 1
avg_Skin_1 = data.Skin[(data.Skin != 0)&(data.Class == 1)].mean()
print avg_Skin_1
data.Skin[(data.Skin == 0)&(data.Class == 1)] = avg_Skin_1
# Out:
# 27.2354570637
# 33.0
# /Users/janeho/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/janeho/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Looking for zeros in 2-Hour serum insulin (mu U/ml)
#data[data.SerumInsulin == 0]
data[data.Skin == 0].count()
# Out:
# TimesPregnant    227
# PGC              227
# DBP              227
# Skin             227
# SerumInsulin     227
# BMI              227
# Pedigree         227
# Age              227
# Class            227
# dtype: int64

# %%
#update 0 SerumInsulin with mean of class = 0 and class = 1 respectively
# Mean of SerumInsulin != 0 and class = 0
avg_SerumInsulin_0 = data.SerumInsulin[(data.SerumInsulin != 0)&(data.Class == 0)].mean()
print avg_SerumInsulin_0
data.SerumInsulin[(data.SerumInsulin == 0)&(data.Class == 0)] = avg_SerumInsulin_0


# Mean of SerumInsulin != 0 and class = 1
avg_SerumInsulin_1 = data.SerumInsulin[(data.SerumInsulin != 0)&(data.Class == 1)].mean()
print avg_SerumInsulin_1
data.SerumInsulin[(data.SerumInsulin == 0)&(data.Class == 1)] = avg_SerumInsulin_1
# Out:
# 130.287878788
# 206.846153846
# /Users/janeho/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Looking for zeros in Pedigree
#data[data.Pedigree == 0]
data[data.Pedigree == 0].count()
# Out:
# TimesPregnant    0
# PGC              0
# DBP              0
# Skin             0
# SerumInsulin     0
# BMI              0
# Pedigree         0
# Age              0
# Class            0
# dtype: int64

# %%
# Looking for zeros in BMI feature
#data[data.BMI == 0]
data[data.BMI == 0].count()
# Out:
# TimesPregnant    11
# PGC              11
# DBP              11
# Skin             11
# SerumInsulin     11
# BMI              11
# Pedigree         11
# Age              11
# Class            11
# dtype: int64

# %%
#update 0 BMI with mean of class = 0 and class = 1 respectively
# Mean of BMI != 0 and class = 0
avg_BMI_0 = data.BMI[(data.BMI != 0)&(data.Class == 0)].mean()
print avg_BMI_0
data.BMI[(data.BMI == 0)&(data.Class == 0)] = avg_BMI_0


# Mean of BMI != 0 and class = 1
avg_BMI_1 = data.BMI[(data.BMI != 0)&(data.Class == 1)].mean()
print avg_BMI_1
data.BMI[(data.BMI == 0)&(data.Class == 1)] = avg_BMI_1
# Out:
# 30.8596741344
# 35.4067669173
# /Users/janeho/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/janeho/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Looking for zeros in Age feature
#data[data.Age == 0]
data[data.Age == 0].count()
# Out:
# TimesPregnant    0
# PGC              0
# DBP              0
# Skin             0
# SerumInsulin     0
# BMI              0
# Pedigree         0
# Age              0
# Class            0
# dtype: int64

# %% [markdown]
# 4. a. Are there any missing data or NULL values? How could they be imputed? Make a choice and impute them or drop them. Justify the choice.
# Although there are no null values, there seems to be some missing data. There are many rows missing in features like tricep skin and 2 hour serum, so I don't think it's a good idea to drop the missing data. I choose to impute the data for the missing attributes. For each feature, I will take the mean of class = 0 and class = 1 and then modify the zeros to the respective average.
#
# Number of times pregnant: There are zeros in this feature, but will assume that it means that female participant has not ever been pregnant.
#
# Plasma Glucose Concentration: Researched online and normal blood glucose levels should be around 70-100 mg/dL. I'm assuming that you can't have a 0 plasma glucose concentration measurement. So for the plasma glucose concentration feature, there are 4 missing values (records 75, 502, 349, 342, 182).
#
# Diastolic blood pressure (mm Hg): can't be zero, so looks like that data is missing. There are 35 values missing for diastolic blood pressure
#
# Triceps skin fold thickness (mm): Zeros/missing in 227 rows.
#
# 2-Hour serum insulin (mu U/ml): Zeros/missing in 374 rows.
#
# Body mass index (weight in kg/(height in m)^2): zeros/missing in 11 rows.
#
# Diabetes pedigree function: no zeros in this feature
#
# Age (years): no missing data in this feature
#
# Class variable (0 or 1): assume no missing data in the feature because 0 means that the individual does not havae diabetes.
#
# b. How many features are there? Are they normalized?
# There are 9 features. I don't think I should normalize the data since i've replaced the missing data with the respective class means.

# %% [markdown]
# 5. Use the KNN classifier from Scikit-learn to predict diabetes occurrence

# %%
from sklearn.cross_validation import train_test_split
import numpy as np

# %%
ind = range(768)
np.random.shuffle(ind)
test_ind = ind[:768/5]
train_ind = ind[768/5:]

# %%
print test_ind
print train_ind
# Out:
# [475, 521, 477, 193, 497, 590, 0, 234, 659, 244, 379, 457, 29, 551, 766, 217, 263, 710, 397, 6, 380, 356, 677, 394, 435, 487, 638, 510, 385, 634, 661, 359, 246, 138, 174, 489, 316, 503, 384, 264, 144, 273, 222, 305, 557, 253, 452, 188, 19, 690, 332, 343, 430, 195, 331, 101, 108, 512, 68, 504, 440, 667, 375, 656, 175, 607, 636, 498, 615, 747, 434, 466, 322, 631, 643, 438, 196, 432, 122, 526, 231, 90, 660, 720, 361, 131, 69, 553, 284, 347, 72, 448, 111, 387, 555, 319, 49, 535, 274, 248, 563, 633, 95, 476, 201, 410, 104, 167, 694, 718, 133, 318, 240, 706, 271, 260, 554, 472, 27, 373, 550, 700, 422, 383, 145, 536, 232, 532, 376, 534, 109, 749, 612, 10, 307, 64, 267, 218, 57, 330, 36, 211, 565, 485, 678, 157, 252, 88, 542, 204, 106, 89, 531]
# ...

# %% [markdown]
# 6. Use Scikit-learn cross-validation routine to evaluate the accuracy of your
# model with a 5-fold CV.
# 7. Plot the 5-fold CV accuracy score as a function of K for k up to 50 neighbors
# 8. Use the Naïve Bayes classifier from Scikit-learn to predict diabetes occurrence
# 9. Compare the 5-fold CV score for Naïve Bayes and for KNN to find which model
# is more accurate
